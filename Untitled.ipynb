# %%
import pandas as pd
import os
import requests
import xmltodict, json
import pymongo

# %%
zip_code_file_dir = "/zipcode_data/uszips.csv"

# %%
df = pd.read_csv(os.getcwd() + zip_code_file_dir)

# %%
df.count()
# Out:
# zip                 33788
# lat                 33788
# lng                 33788
# city                33788
# state_id            33788
# state_name          33788
# zcta                33788
# parent_zcta             0
# population          32714
# density             32714
# county_fips         33788
# county_name         33788
# county_weights      33788
# county_names_all    33788
# county_fips_all     33788
# imprecise           33788
# military            33788
# timezone            33788
# dtype: int64

# %%
headers = {
  'authority': 'www.tacobell.com',
  'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
  'accept-language': 'en-US,en;q=0.9',
  'cache-control': 'no-cache',
  'cookie': 'bm_sz=E4D6D16C86A89C7B15288B0ADD267568~~4273206~4601158; bm_mi=96C7CD6B5979530E46F9024EFA7D0F71~~1; _gcl_au=1.1.2144491266.1653433494; seerid=89809.79682805699; seerid=89809.79682805699; JSESSIONID=10F3A5B4C635172F2D94A485D368B6F9; CSRFToken=40b6d780-8eca-441d-ad21-9ff44a41fde0; AWSELB=3119AFC114622B4A1B853AE9C5E9EE3FDC77CA92FE1E864A88B86DCABE5B2BDC1660B3CDB4063CAD7A343484FD805257476DC3A0ABAC96C3C476F170E9F095C2F388FE54FF; AWSELBCORS=3119AFC114622B4A1B853AE9C5E9EE3FDC77CA92FE1E864A88B86DCABE5B2BDC1660B3CDB4063CAD7A343484FD805257476DC3A0ABAC96C3C476F170E9F095C2F388FE54FF; ak_bmsc=1516147433781D5C78D154733F8E62CA~000000000000000000000000000000~...; _scid=b1380dfe-1aae-4a69-96b2-419fe393af79; _gid=GA1.2.897576685.1653433496; _cs_c=0; _sctr=1|1653375600000; _pin_unauth=dWlkPU9EQmlZamsxWXpBdE1XTmpOaTAwTm1Nd0xUa3pPR010WVRnNVltUTJaVFkwWVRoaA; _clck=12mvpme|1|f1q|0; _cs_cvars=%7B%7D; _ga_81J1R64GQ6=GS1.1.1653433493.1.1.1653433517.36; _uetsid=ecc0e0b0dbb511ec9fdcc754ab3ca51e; _uetvid=ecc0fce0dbb511ecb7a96f7ce1c185ff; _ga=GA1.2.962027013.1653433494; _derived_epik=dj0yJnU9U3FDdE1iQkx5NHY1eEhLb0hoa0xCdWkycGUtX1NrNWombj03Z0NmMFo0elB0RDhBMWJwS2dWTkRBJm09ZiZ0PUFBQUFBR0tOWkxFJnJtPWYmcnQ9QUFBQUFHS05aTEU; _hjSessionUser_1676329=eyJpZCI6IjgxNTA4MTc1LTU2YWQtNWU2YS05ZDRlLTBiNGQ0NGUyNjkwOSIsImNyZWF0ZWQiOjE2NTM0MzQwOTc2NjksImV4aXN0aW5nIjp0cnVlfQ==; _clsk=ws7hzy|1653434303730|4|0|e.clarity.ms/collect; _abck=0D3138B1226DEFEF7C82787B33F53408~-1~...~-1~-1~-1; _dd_s=rum=0&expire=1653436472558&logs=0; _cs_id=76c0eeb9-ccf7-a3e1-b51a-5550256c4a1a.1653433496.2.1653435572.1653435572.1625591181.1687597496205; _cs_s=1.0.0.1653437372555; AWSALB=XKoqGZpIZI+cTKrPNL2RT+HwQ01/uISFRt62e1JrBG23NK2GAru5qE9+tVmdZ/TsmpRbTSILOaz8XxDa2bZCB6wuXTs5PT9P6lNc9TsnY1JZI+EO1Psxv94fF/GI; AWSALBCORS=XKoqGZpIZI+cTKrPNL2RT+HwQ01/uISFRt62e1JrBG23NK2GAru5qE9+tVmdZ/TsmpRbTSILOaz8XxDa2bZCB6wuXTs5PT9P6lNc9TsnY1JZI+EO1Psxv94fF/GI; akavpau_ProdTB=1653436831~id=3b8b3ad4e04395a14b6c0e5768450525; bm_sv=D3A35EAF0D46D0F0024C8056D48B8E76~~1; _abck=B5D2EBA95968888ED289493F8A5EF208~-1~~-1~-1~-1; ak_bmsc=A2743D8B172D43F3AADBA90163CDAE84~000000000000000000000000000000~; bm_sz=FCF3913D2767FE87FE60D0CE0D16E453~~4470580~3687986; AWSALB=+dmJRQb+x5zMkSoQO0wA3O7XLqVvMj8dc2ZLZ74epBXSh46P5aggXkTfqdDOVtKOtqMc5tXeVgXIh2vwfQg6FiPsYx63KeYazeBaIjXsBqaOnToGnQPagy7v4qmN; AWSALBCORS=+dmJRQb+x5zMkSoQO0wA3O7XLqVvMj8dc2ZLZ74epBXSh46P5aggXkTfqdDOVtKOtqMc5tXeVgXIh2vwfQg6FiPsYx63KeYazeBaIjXsBqaOnToGnQPagy7v4qmN; akavpau_ProdTB=1653436253~id=a6a49cc88e38b1f58330b4fc4f0b853b; bm_sv=D03947F83BD9C841C87D8892E94B4C81~~1',
  'pragma': 'no-cache',
  'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="101", "Google Chrome";v="101"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"macOS"',
  'sec-fetch-dest': 'document',
  'sec-fetch-mode': 'navigate',
  'sec-fetch-site': 'none',
  'sec-fetch-user': '?1',
  'upgrade-insecure-requests': '1',
  'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.64 Safari/537.36'
}

taco_bell_locator = "https://www.tacobell.com/tacobellwebservices/v2/tacobell/stores?"

# %%
df[df.state_id == "CA"]
# Out:
#          zip       lat        lng              city state_id  state_name  \
# 30601  90001  33.97365 -118.24904       Los Angeles       CA  California
# 30602  90002  33.94906 -118.24679       Los Angeles       CA  California
# 30603  90003  33.96409 -118.27368       Los Angeles       CA  California
# 30604  90004  34.07624 -118.31101       Los Angeles       CA  California
# 30605  90005  34.05939 -118.30909       Los Angeles       CA  California
# 30606  90006  34.04807 -118.29411       Los Angeles       CA  California
# 30607  90007  34.02819 -118.28486       Los Angeles       CA  California
# 30608  90008  34.01037 -118.34280       Los Angeles       CA  California
# 30609  90010  34.06209 -118.31262       Los Angeles       CA  California
# 30610  90011  34.00689 -118.25861       Los Angeles       CA  California
# 30611  90012  34.06679 -118.23878       Los Angeles       CA  California
# 30612  90013  34.04435 -118.24000       Los Angeles       CA  California
# ...

# %%
resp = requests.get(curr_locator, headers=headers)
json_resp = xmltodict.parse(resp.text)

# %%
json_resp.keys()
# Out:
# odict_keys(['storeFinderSearchPage'])

# %%
json_resp['storeFinderSearchPage']["nearByStores"][0]["storeNumber"]
# Out:
# '033621'

# %%
json_resp['storeFinderSearchPage']["nearByStores"][0]["address"]
# Out:
# OrderedDict([('country', OrderedDict([('isocode', 'US')])),
#              ('id', '8796688777239'),
#              ('line1', '2543 Slauson Ave'),
#              ('postalCode', '90255'),
#              ('region', OrderedDict([('isocode', 'US-CA')])),
#              ('town', 'Huntington Park')])

# %%
json_resp['storeFinderSearchPage']["nearByStores"][0]
# Out:
# OrderedDict([('address',
#               OrderedDict([('country', OrderedDict([('isocode', 'US')])),
#                            ('id', '8796688777239'),
#                            ('line1', '2543 Slauson Ave'),
#                            ('postalCode', '90255'),
#                            ('region', OrderedDict([('isocode', 'US-CA')])),
#                            ('town', 'Huntington Park')])),
#              ('autoCheckIn', 'false'),
#              ('capabilities',
#               OrderedDict([('breakfast', 'true'),
#                            ('cateringEnabled', 'false'),
#                            ('deliveryEnabled', 'true'),
#                            ('driveThru', 'true'),
#                            ('driveThruPriorityPickupLane', 'false'),
#                            ('ghSiteId', '923571'),
#                            ('isCurbSideAvailable', 'false'),
#                            ('isPickRestaurant', 'true'),
# ...

# %%
tb_menu_url = "https://www.tacobell.com/tacobellwebservices/v2/tacobell/products/menu/029318"
resp = requests.get(tb_menu_url, headers=headers)
print(resp.json()["menuProductCategories"][0]["products"])
# Out:
# [{'code': '22303', 'name': 'Mexican Pizza', 'url': '/food/specialties/mexican-pizza', 'purchasable': True, 'price': {'currencyIso': 'USD', 'value': 5.29, 'priceType': 'BUY', 'formattedValue': '$5.29'}, 'images': [{'imageType': 'PRIMARY', 'format': '269x269', 'url': 'https://www.tacobell.com/images/22303_mexican_pizza_269x269.jpg'}, {'imageType': 'PRIMARY', 'format': '750x340', 'url': 'https://www.tacobell.com/images/22303_mexican_pizza_750x340.jpg'}, {'imageType': 'PRIMARY', 'format': '750x610', 'url': 'https://www.tacobell.com/images/22303_mexican_pizza_750x610.jpg'}, {'imageType': 'PRIMARY', 'format': '750x660', 'url': 'https://www.tacobell.com/images/22303_mexican_pizza_750x660.jpg'}], 'categories': [{'code': 'food'}, {'code': 'specialties'}, {'code': 'new'}], 'priceRange': {}, 'productType': 'Standard', 'itemType': 'Product', 'foodType': 'Sellable_food', 'calories': '530', 'maxOrderQuantity': 50, 'maxProductCount': 0, 'modifiable': True, 'sodiumIndication': False, 'productCount':
# ...

# %%
test = json.loads(json.dumps(json_resp['storeFinderSearchPage']["nearByStores"][0]))

# %%
test.keys()
# Out:
# dict_keys(['address', 'autoCheckIn', 'capabilities', 'currentOnlineAvailable', 'driveThruPriorityPickupLane', 'formattedDistance', 'geoPoint', 'geofencingEnabled', 'isCurbSideAvailable', 'mapIcon', 'name', 'openingHours', 'phoneNumber', 'pickupShelves', 'pickupStoreStatusForCheckout', 'pickupStoreStatusForLocation', 'previouslyOrdered', 'qrCodeEnabled', 'roundUpFlag', 'storeNumber', 'storeStatus', 'timeZone', 'todayBusinessHours'])

# %%
del_keys = ["formattedDistance", "mapIcon"]

# %%
DB_HOST = "cluster0.a6h2z.mongodb.net"
DB_USERNAME = "root"
DB_PASSWORD = 'wec4lyfe'
DB_NAME = 'Cluster0'

host=f"mongodb+srv://{DB_USERNAME}:{DB_PASSWORD}@{DB_HOST}/{DB_NAME}?retryWrites=true&w=majority"

# %%
meta_data["storeNumber"]
# Out:
# '033621'

# %%
menu_resp = xmltodict.parse(resp.text)
# Out:
# ---------------------------------------------------------------------------
# ExpatError                                Traceback (most recent call last)
# <ipython-input-111-386433365ca6> in <module>
# ----> 1 menu_resp = xmltodict.parse(resp.text)
#
# /anaconda3/envs/py36/lib/python3.6/site-packages/xmltodict.py in parse(xml_input, encoding, expat, process_namespaces, namespace_separator, disable_entities, **kwargs)
#     325         parser.ParseFile(xml_input)
#     326     else:
# --> 327         parser.Parse(xml_input, True)
#     328     return handler.item
#     329
#
# ExpatError: not well-formed (invalid token): line 1, column 0

# %%
tb_menu = json.loads(resp.text)

# %%
tb_menu["menuProductCategories"][0]["products"]

23326
22303
# Out:
# [{'code': '22303',
#   'name': 'Mexican Pizza',
#   'url': '/food/specialties/mexican-pizza',
#   'purchasable': True,
#   'price': {'currencyIso': 'USD',
#    'value': 4.99,
#    'priceType': 'BUY',
#    'formattedValue': '$4.99'},
#   'images': [{'imageType': 'PRIMARY',
#     'format': '269x269',
#     'url': 'https://www.tacobell.com/images/22303_mexican_pizza_269x269.jpg'},
#    {'imageType': 'PRIMARY',
#     'format': '750x340',
#     'url': 'https://www.tacobell.com/images/22303_mexican_pizza_750x340.jpg'},
#    {'imageType': 'PRIMARY',
#     'format': '750x610',
#     'url': 'https://www.tacobell.com/images/22303_mexican_pizza_750x610.jpg'},
#    {'imageType': 'PRIMARY',
#     'format': '750x660',
#     'url': 'https://www.tacobell.com/images/22303_mexican_pizza_750x660.jpg'}],
#   'categories': [{'code': 'food'}, {'code': 'specialties'}, {'code': 'new'}],
#   'priceRange': {},
#   'productType': 'Standard',
#   'itemType': 'Product',
#   'foodType': 'Sellable_food',
# ...

# %%
for 




#store metadata
meta_data = json.loads(json.dumps(json_resp['storeFinderSearchPage']["nearByStores"][0]))
for key in del_keys:
    del meta_data[key]
store_name = meta_data["storeNumber"]
# Out:
#   File "<ipython-input-122-baafacb8a104>", line 3
#     for
#         ^
# SyntaxError: invalid syntax

# %%
taco_bell_locations = {}
loc_count = 0
for index, row in df.iterrows():
    lat = row["lat"]
    lng = row["lng"]
    curr_locator = taco_bell_locator + f"latitude={lat}&longitude={lng}"
    resp = requests.get(curr_locator, headers=headers)
    json_resp = xmltodict.parse(resp.text)
    if "nearByStores" not in json_resp['storeFinderSearchPage']:
        pass
    else:
        nearby_stores = json_resp['storeFinderSearchPage']["nearByStores"]
        for store in nearby_stores:
            if store['storeNumber'] not in taco_bell_locations.keys():
                store_meta_data = json.loads(json.dumps(json_resp['storeFinderSearchPage']["nearByStores"][0]))
                storage = {"lat":store_meta_data["geoPoint"]["latitude"], "lng":store_meta_data["geoPoint"]["longitude"], "remainder_data":store_meta_data}
                #mexican pizza logic
                tb_menu_url = f"https://www.tacobell.com/tacobellwebservices/v2/tacobell/products/menu/{store['storeNumber']}"
                try:
                    resp = requests.get(tb_menu_url, headers=headers)
                    store_menu = resp.json()
                    store_menu_products = store_menu["menuProductCategories"][0]["products"]
                    count = 0
                    storage["has_veggie_mp"] = False
                    storage["has_beef_mp"] = False
                    for product in products:
                        if product["code"] == "23326":
                            print(f"STORE {store['storeNumber']} has the mexican pizza!")
                            storage["has_veggie_mp"] = True
                            count += 1
                        if product["code"] == "22303":
                            storage["has_beef_mp"] = True
                            count += 1
                        if count == 2:
                            break
                    taco_bell_locations[store['storeNumber']] = storage
                except Exception as e:
                    print("broke on: ", index, row["state_name"], tb_menu_url)
                    print(e)
    if loc_count / 100 == 0:
        print("COUNT: ", loc_count, row['state_name'])
    loc_count += 1
            
                    
            
            O(N)
# Out:
# COUNT:  0 Puerto Rico
# broke on:  138 Massachusetts https://www.tacobell.com/tacobellwebservices/v2/tacobell/products/menu/029245
# name 'products' is not defined
# broke on:  138 Massachusetts https://www.tacobell.com/tacobellwebservices/v2/tacobell/products/menu/033637
# name 'products' is not defined
# broke on:  138 Massachusetts https://www.tacobell.com/tacobellwebservices/v2/tacobell/products/menu/029246
# name 'products' is not defined
# broke on:  138 Massachusetts https://www.tacobell.com/tacobellwebservices/v2/tacobell/products/menu/029248
# name 'products' is not defined
# broke on:  138 Massachusetts https://www.tacobell.com/tacobellwebservices/v2/tacobell/products/menu/031222
# name 'products' is not defined
# broke on:  138 Massachusetts https://www.tacobell.com/tacobellwebservices/v2/tacobell/products/menu/029301
# name 'products' is not defined
# broke on:  138 Massachusetts https://www.tacobell.com/tacobellwebservices/v2/tacobell/products/menu/034829
# ...

# %%
df.head(100)
# Out:
#     zip       lat       lng           city state_id      state_name  zcta  \
# 0   601  18.18027 -66.75266       Adjuntas       PR     Puerto Rico  True
# 1   602  18.36075 -67.17541         Aguada       PR     Puerto Rico  True
# 2   603  18.45744 -67.12225      Aguadilla       PR     Puerto Rico  True
# 3   606  18.16585 -66.93716        Maricao       PR     Puerto Rico  True
# 4   610  18.29110 -67.12243         Anasco       PR     Puerto Rico  True
# 5   611  18.27698 -66.80688        Angeles       PR     Puerto Rico  True
# 6   612  18.41283 -66.70510        Arecibo       PR     Puerto Rico  True
# 7   616  18.41878 -66.66790       Bajadero       PR     Puerto Rico  True
# 8   617  18.44598 -66.56006    Barceloneta       PR     Puerto Rico  True
# 9   622  17.98892 -67.15660       Boqueron       PR     Puerto Rico  True
# 10  623  18.08429 -67.15336      Cabo Rojo       PR     Puerto Rico  True
# 11  624  18.05905 -66.71932       Penuelas       PR     Puerto Rico  True
# ...

# %%
json.loads(json.dumps(json_resp['storeFinderSearchPage']["nearByStores"][0]))["geoPoint"]
# Out:
# {'latitude': '33.9894', 'longitude': '-118.226'}

# %%
# Out:
# {'navigationFacets': {'title': "Can't decide? How about something...",
#   'facets': [{'id': 'meaty', 'value': 'true', 'name': 'Meaty'},
#    {'id': 'spicy', 'value': 'true', 'name': 'Spicy'},
#    {'id': 'cheesy', 'value': 'true', 'name': 'Cheesy'}]},
#  'navigationCollections': {'title': 'Still not sure? Try something from these selections...',
#   'collections': [{'id': 'on-a-budget',
#     'value': 'On a Budget',
#     'image': {'url': 'https://www.tacobell.com/medias/OnABudget-684x296.png?context=bWFzdGVyfGltYWdlc3w0MjU0NDl8aW1hZ2UvcG5nfGltYWdlcy9oNDQvaDZiLzkxNTg0NTIyMTU4MzgucG5nfDNiZmNjMzU4M2YxZDJkZjQxMTZkYTE1OTlkOWQzM2ZhODdhMWVhNjlkZGRkNTk3YzliOWRhN2Y4ZGQ4NzYwZGE'}},
#    {'id': 'great-for-groups',
#     'value': 'Great For Groups',
# ...

# %%
type(resp.json())
# Out:
# dict
